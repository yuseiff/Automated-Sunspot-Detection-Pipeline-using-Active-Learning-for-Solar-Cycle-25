# %%
import pandas as pd

results3 = pd.read_csv(r'Computer Vision Code\YOLOv26\YOLO26_Dataset Version6\Preprocessing3\YOLO26_N_V6_V3\results.csv')
results3.tail(10)
# Out:
#      epoch     time  train/box_loss  train/cls_loss  train/l1_loss  \
# 290    291  35028.3         2.16526         0.97746        0.00158
# 291    292  35143.1         2.13903         0.96843        0.00155
# 292    293  35257.9         2.12755         0.96173        0.00154
# 293    294  35374.5         2.12290         0.95401        0.00153
# 294    295  35490.8         2.12216         0.95129        0.00153
# 295    296  35606.6         2.11624         0.95192        0.00152
# 296    297  35722.9         2.12154         0.95393        0.00153
# 297    298  35839.0         2.11314         0.94919        0.00152
# 298    299  35955.1         2.10899         0.94406        0.00151
# 299    300  36071.7         2.10384         0.94747        0.00151
#
#      metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 290               0.76221            0.50933           0.54087
# 291               0.76088            0.51033           0.54106
# 292               0.76081            0.51000           0.54106
# 293               0.76140            0.50991           0.54090
# 294               0.76136            0.50954           0.54063
# 295               0.75993            0.50997           0.54053
# 296               0.75961            0.51012           0.54069
# 297               0.76079            0.51050           0.54085
# 298               0.76147            0.51029           0.54124
# 299               0.76082            0.51046           0.54088
#
#      metrics/mAP50-95(B)  val/box_loss  val/cls_loss  val/l1_loss    lr/pg0  \
# 290              0.26569       2.09976       0.90260      0.00119  0.001290
# 291              0.26586       2.09926       0.90257      0.00119  0.001191
# 292              0.26576       2.09974       0.90212      0.00119  0.001092
# 293              0.26580       2.09987       0.90071      0.00119  0.000993
# 294              0.26573       2.09883       0.90124      0.00119  0.000894
# 295              0.26581       2.09892       0.90099      0.00119  0.000795
# 296              0.26605       2.09838       0.90046      0.00119  0.000696
# 297              0.26599       2.09957       0.89956      0.00119  0.000597
# 298              0.26622       2.09867       0.89945      0.00119  0.000498
# 299              0.26594       2.09951       0.89894      0.00119  0.000399
#
#        lr/pg1    lr/pg2    lr/pg3    lr/pg4    lr/pg5    lr/pg6    lr/pg7
# 290  0.000430  0.001290  0.000430  0.001290  0.000430  0.001290  0.000430
# 291  0.000397  0.001191  0.000397  0.001191  0.000397  0.001191  0.000397
# 292  0.000364  0.001092  0.000364  0.001092  0.000364  0.001092  0.000364
# 293  0.000331  0.000993  0.000331  0.000993  0.000331  0.000993  0.000331
# 294  0.000298  0.000894  0.000298  0.000894  0.000298  0.000894  0.000298
# 295  0.000265  0.000795  0.000265  0.000795  0.000265  0.000795  0.000265
# 296  0.000232  0.000696  0.000232  0.000696  0.000232  0.000696  0.000232
# 297  0.000199  0.000597  0.000199  0.000597  0.000199  0.000597  0.000199
# 298  0.000166  0.000498  0.000166  0.000498  0.000166  0.000498  0.000166
# 299  0.000133  0.000399  0.000133  0.000399  0.000133  0.000399  0.000133

# %%
print('max mAP@0.5:', results3['metrics/mAP50(B)'].max())
print('mAP@0.5:0.95 for max mAP@0.5:',results3['metrics/mAP50-95(B)'].iloc[results3['metrics/mAP50(B)'].idxmax()])
print('precision for max mAP@0.5',results3['metrics/precision(B)'].iloc[results3['metrics/mAP50(B)'].idxmax()])
print('recall for max mAP@0.5',results3['metrics/recall(B)'].iloc[results3['metrics/mAP50(B)'].idxmax()])
f11 = 2* (results3['metrics/recall(B)'].iloc[results3['metrics/mAP50(B)'].idxmax()] * results3['metrics/precision(B)'].iloc[results3['metrics/mAP50(B)'].idxmax()])/(results3['metrics/recall(B)'].iloc[results3['metrics/mAP50(B)'].idxmax()]+results3['metrics/precision(B)'].iloc[results3['metrics/mAP50(B)'].idxmax()])
print('F1 for max mAP@0.5',f11)
print(50*'*')
print('max mAP@0.5:0.95:', results3['metrics/mAP50-95(B)'].max())
print('mAP@0.5 for max mAP@0.5:0.95',results3['metrics/mAP50(B)'].iloc[results3['metrics/mAP50-95(B)'].idxmax()])
print('precision for max mAP@0.5:0.95',results3['metrics/precision(B)'].iloc[results3['metrics/mAP50-95(B)'].idxmax()])
print('recall for max mAP@0.5:0.95',results3['metrics/recall(B)'].iloc[results3['metrics/mAP50-95(B)'].idxmax()])
f12 = 2*(results3['metrics/recall(B)'].iloc[results3['metrics/mAP50-95(B)'].idxmax()] * results3['metrics/precision(B)'].iloc[results3['metrics/mAP50-95(B)'].idxmax()])/(results3['metrics/recall(B)'].iloc[results3['metrics/mAP50-95(B)'].idxmax()]+results3['metrics/precision(B)'].iloc[results3['metrics/mAP50-95(B)'].idxmax()])
print('F1 for max mAP@0.5',f12)
print(50*'*')
print('max mAP@0.5:', results3['metrics/mAP50(B)'].idxmax())
print('max mAP@0.5:0.95:', results3['metrics/mAP50-95(B)'].idxmax())
# Out:
# max mAP@0.5: 0.54124
# mAP@0.5:0.95 for max mAP@0.5: 0.26622
# precision for max mAP@0.5 0.76147
# recall for max mAP@0.5 0.51029
# F1 for max mAP@0.5 0.6110752442284708
# **************************************************
# max mAP@0.5:0.95: 0.26622
# mAP@0.5 for max mAP@0.5:0.95 0.54124
# precision for max mAP@0.5:0.95 0.76147
# recall for max mAP@0.5:0.95 0.51029
# F1 for max mAP@0.5 0.6110752442284708
# **************************************************
# max mAP@0.5: 298
# max mAP@0.5:0.95: 298
